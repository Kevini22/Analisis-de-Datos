# %% [markdown]
# <p Style="text-align: right">02/06/2023</p>
# <p style="text-align: right">Semana 3</p>
#
# <img src="Benjen Banana Glorious.jpg" alt="Benjen Holding a Banana with His Mouth" width="250" height="250">
#
# <h1 Style="color:#D2691E; text-align: center">Benjen</h1>
#
# <p Style="font-family:Segoe UI">El nombre de mi dueño es Kevin. Nos conocemos desde hace poco más de dos años. Lo molesto todo el tiempo, pero sé que me ama porque siempre me da besos y me abraza. Aquí están las 3 razones principales por las que creo que me ama tanto:</p>
#
# <ol>
#     <li #00FA9A Style="font-family:Segoe UI">Porque soy genial!</li>
#     <li Style="font-family:Segoe UI">Siempre estoy lleno de energia !!</li>
#     <li Style="font-family:Segoe UI">Y siempre como la comida que él no quiere comer!!!</li>
#
# </ol>

# %% [markdown]
# <p style="text-align: right">9/06/2023</p>
# <p style="text-align: right">Semana 4</p>
#
# <h2 style="color:#50C878">1. Carga de Set de Datos para Análisis</h2>
#
# <p>Para poder crear un modelo de aprendizaje automático, lo primero que
# necesitamos hacer es cargar los datos que se van a usar para crear el
# modelo de aprendizaje automático.
#
# Y para realizar esto, podemos usar 5 metodos diferentes.
# <ol>
#     <li Style="font-family:Segoe UI">CSV</li>
#     <li Style="font-family:Segoe UI">NumPy</li>
#     <li Style="font-family:Segoe UI">Pandas</li>
#     <li Style="font-family:Segoe UI">URL</li>
#     <li Style="font-family:Segoe UI">Otras Librerias</li>
# </ol>
# </p>

# %% [markdown]
# <h3>Modulo CSV</h3>
# <p>
#     La mas simple de todos los metodos.
#     Para extraer, usamos la funcion open(), y despues ejecutamos csv.reader().
#     csv.reader() lee cada linea y crea la lista de todas las columnas en
#     el objeto reader
# </p>
#
# <h3>Numpy</h3>
# <p>
#
# </p>
#
# <h3>Pandas</h3>
# <p>
# </p>
#
# <h3>URL</h3>
# <p>
# </p>
#
# <h3>Otras Librerias</h3>
# <p>
# </p>

# %% [markdown]
# <p style="text-align: right">16/06/2023</p>
# <p style="text-align: right">Semana 5</p>
#
# <h2 style="color:#50C878">2. Carga y estandarizacion de los set de datos</h2>
#
# <ol>
#     <li Style="font-family:Segoe UI">Importar las librerias necesarias</li>
#     <li Style="font-family:Segoe UI">Importar los set de datos</li>
#     <li Style="font-family:Segoe UI">Revision de Encabezados</li>
#     <li Style="font-family:Segoe UI">Fast EDA - Revision estadistica general del set de datos</li>
#     <li Style="font-family:Segoe UI">Unir los set de datos</li>
# </ol>

# %% [markdown]
# <h5 style="color:#483D8B">2.1 Importacion de librerias</h5>

# %%
import pandas as pd #Se usa para el manejo de dataFrame
import numpy as np #Se usa para el manejo de estructuras de datos
import matplotlib.pyplot as plt # Se usa para crear graficos
import matplotlib as mpl #Se usa para configurar las graficas

# %% [markdown]
# <h5 style="color:#483D8B">2.2 Importacion de set de datos</h5>

# %%
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors", 
       "style", "wheels", "engine", "base", "length", "width", "heingt",
       "curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
       "compression", "horsepower", "peak", "City", "Higway", "price"]

df_ler_autos = pd.read_csv("autos.csv", names=cols)
df_ler2_autos = pd.read_csv("Autos1.csv", names=cols)

# %%
df_ler_autos.shape
# Out:
# (197, 26)

# %%
df_ler2_autos.shape
# Out:
# (29, 26)

# %%
df_ler_autos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
df_ler_autos.tail(5)
# Out:
#      symboling normalized        make    fuel aspiration doors  style wheels  \
# 192          0          ?  volkswagen  diesel      turbo  four  sedan    fwd
# 193          0          ?  volkswagen     gas        std  four  wagon    fwd
# 194         -2        103       volvo     gas        std  four  sedan    rwd
# 195         -1         74       volvo     gas        std  four  wagon    rwd
# 196         -2        103       volvo     gas        std  four  sedan    rwd
#
#     engine   base  ...  engine-size  system  bore  stroke compression  \
# 192  front  100.4  ...           97     idi  3.01    3.40        23.0
# 193  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 194  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 195  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 196  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak City Higway  price
# 192         68  4500   33     38  13845
# ...

# %%
df_ler2_autos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engine-size  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
#
#    peak City  Higway  price
# ...

# %%
df_ler_autos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engine-size  compression        City      Higway
# count   197.000000   197.000000   197.000000  197.000000  197.000000
# mean   2534.796954   126.263959    10.128020   25.416244   30.984772
# std     520.401159    42.282594     3.934467    6.566717    6.908644
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# ...

# %%
df_ler2_autos.describe()
# Out:
#        symboling        base      length      width     heingt         curb  \
# count  29.000000   29.000000   29.000000  29.000000  29.000000    29.000000
# mean    0.827586  100.103448  177.186207  66.134483  54.406897  2580.000000
# std     1.691765    3.082726    7.178327   0.917012   1.666676   310.887325
# min    -2.000000   94.500000  159.300000  64.000000  51.400000  2209.000000
# 25%    -1.000000   97.300000  171.700000  65.500000  53.000000  2300.000000
# 50%     2.000000  100.400000  176.200000  66.500000  54.900000  2536.000000
# 75%     2.000000  102.400000  183.100000  66.900000  55.700000  2912.000000
# max     3.000000  104.500000  188.800000  67.700000  57.500000  3151.000000
#
#        engine-size       bore     stroke  compression  horsepower  \
# count    29.000000  29.000000  29.000000    29.000000   29.000000
# mean    128.000000   3.330690   3.402069    11.475862  102.413793
# std      23.653752   0.240088   0.108278     5.318610   29.382353
# ...

# %%
df_ler_autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    197 non-null    int64
#  1   normalized   197 non-null    object
#  2   make         197 non-null    object
#  3   fuel         197 non-null    object
#  4   aspiration   197 non-null    object
#  5   doors        197 non-null    object
#  6   style        197 non-null    object
#  7   wheels       197 non-null    object
#  8   engine       197 non-null    object
#  9   base         197 non-null    float64
#  10  length       197 non-null    float64
#  11  width        197 non-null    float64
#  12  heingt       197 non-null    float64
#  13  curb         197 non-null    int64
#  14  engineType   197 non-null    object
#  15  Cylinders    197 non-null    object
#  16  engine-size  197 non-null    int64
#  17  system       197 non-null    object
# ...

# %% [markdown]
# <h5 style="color:#483D8B">2.3 Revision de encabezados</h5>
#
# <p>Lo que se busca es estandarizar el nombre de cada columna de los set de datos que se carguen a los proyectos de python.</p>
#
# <ul>
#     <li>Nombre de columnas no deben contener espacios en blanco</li>
#     <li>Nombres de columnas no deben comenzar con numeros</li>
#     <li>No deben de existir nombres repetidos</li>
#     <li>Si el nombre tiene 2 palabras la letra inicial de la segunda palabra           debe ir en mayuscula</li>
#     <li>Recomendacios la primera palabra debe ser en minusculas</li>
# </ul>

# %%
df_ler_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_ler2_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_ler_autos.rename({'engine-size': 'engineSize'}, axis=1, inplace=True)
df_ler_autos.rename({'Cylinders': 'cylinders'}, axis=1, inplace=True)
df_ler_autos.rename({'City': 'city'}, axis=1, inplace=True)
df_ler_autos.rename({'Higway': 'higway'}, axis=1, inplace=True)
df_ler_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'cylinders', 'engineSize', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'city', 'higway',
#        'price'],
#       dtype='object')

# %%
df_ler2_autos.rename({'engine-size': 'engineSize'}, axis=1, inplace=True)
df_ler2_autos.rename({'Cylinders': 'cylinders'}, axis=1, inplace=True)
df_ler2_autos.rename({'City': 'city'}, axis=1, inplace=True)
df_ler2_autos.rename({'Higway': 'higway'}, axis=1, inplace=True)
df_ler2_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'cylinders', 'engineSize', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'city', 'higway',
#        'price'],
#       dtype='object')

# %% [markdown]
# <h2 style="color:#50C878">3. Unir (Integrar) los Set de Datos</h4>

# %%
tplDataFrame = [df_ler_autos, df_ler2_autos]
dfAutos = pd.concat(tplDataFrame)
dfAutos.shape
# Out:
# (226, 26)

# %%
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %%
df_ler_autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    197 non-null    int64
#  1   normalized   197 non-null    object
#  2   make         197 non-null    object
#  3   fuel         197 non-null    object
#  4   aspiration   197 non-null    object
#  5   doors        197 non-null    object
#  6   style        197 non-null    object
#  7   wheels       197 non-null    object
#  8   engine       197 non-null    object
#  9   base         197 non-null    float64
#  10  length       197 non-null    float64
#  11  width        197 non-null    float64
#  12  heingt       197 non-null    float64
#  13  curb         197 non-null    int64
#  14  engineType   197 non-null    object
#  15  cylinders    197 non-null    object
#  16  engineSize   197 non-null    int64
#  17  system       197 non-null    object
# ...

# %% [markdown]
# <p style="text-align: right">30/06/2023</p>
# <p style="text-align: right">Semana 7</p>
#
# <h2 style="color:#50C878">4. Manejo de valores faltantes</h2>
#
# <ol>
#     <li>Identificar como se visualizan los valores faltantes en DF</li>
#     <li>Contar la cantidad de valores faltantes por variable (Columnas)</li>
#     <li>Imputacion simple de valores numericos</li>
#     <li>Imputacion simple de valores categoricos</li>
#     <li>Eliminar observaciones del DF</li>
# </ol>
#
# <h5 style="color:#483D8B">4.1 identificar como se visualizan los valores faltantes en DF</h5>

# %%
dfAutos.replace('?', np.nan, inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %%
dfAutos.tail(5)
# Out:
#     symboling normalized        make    fuel aspiration doors  style wheels  \
# 24          0        NaN  volkswagen  diesel      turbo  four  sedan    fwd
# 25          0        NaN  volkswagen     gas        std  four  wagon    fwd
# 26         -2        103       volvo     gas        std  four  sedan    rwd
# 27         -1         74       volvo     gas        std  four  wagon    rwd
# 28         -2        103       volvo     gas        std  four  sedan    rwd
#
#    engine   base  ...  engineSize  system  bore  stroke compression  \
# 24  front  100.4  ...          97     idi  3.01     3.4        23.0
# 25  front  100.4  ...         109    mpfi  3.19     3.4         9.0
# 26  front  104.3  ...         141    mpfi  3.78    3.15         9.5
# 27  front  104.3  ...         141    mpfi  3.78    3.15         9.5
# 28  front  104.3  ...         141    mpfi  3.78    3.15         9.5
#
#    horsepower  peak city higway  price
# 24         68  4500   33     38  13845
# ...

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226 entries, 0 to 28
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    226 non-null    int64
#  1   normalized   180 non-null    object
#  2   make         226 non-null    object
#  3   fuel         226 non-null    object
#  4   aspiration   226 non-null    object
#  5   doors        224 non-null    object
#  6   style        226 non-null    object
#  7   wheels       226 non-null    object
#  8   engine       226 non-null    object
#  9   base         226 non-null    float64
#  10  length       226 non-null    float64
#  11  width        226 non-null    float64
#  12  heingt       226 non-null    float64
#  13  curb         226 non-null    int64
#  14  engineType   226 non-null    object
#  15  cylinders    226 non-null    object
#  16  engineSize   226 non-null    int64
#  17  system       226 non-null    object
# ...

# %%
dfAutos.replace("?", np.nan, inplace=True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h5 style="color:#483D8B">4.2 Contar la cantidad de valores faltantes por variable (Columnas)</h5>

# %%
dfTemp=dfAutos.isnull()
dfTemp.head(5)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False        True  False  False       False  False  False   False
# 1      False        True  False  False       False  False  False   False
# 2      False        True  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
#
#    engine   base  ...  engineSize  system   bore  stroke  compression  \
# 0   False  False  ...       False   False  False   False        False
# 1   False  False  ...       False   False  False   False        False
# 2   False  False  ...       False   False  False   False        False
# 3   False  False  ...       False   False  False   False        False
# 4   False  False  ...       False   False  False   False        False
#
#    horsepower   peak   city  higway  price
# 0       False  False  False   False  False
# ...

# %%
for column in dfTemp.columns.values.tolist():
    print(column)
    print(dfTemp[column].value_counts())
    print("")
# Out:
# symboling
# False    226
# Name: symboling, dtype: int64
#
# normalized
# False    180
# True      46
# Name: normalized, dtype: int64
#
# make
# False    226
# Name: make, dtype: int64
#
# fuel
# False    226
# Name: fuel, dtype: int64
#
# aspiration
# False    226
# Name: aspiration, dtype: int64
#
# doors
# False    224
# True       2
# Name: doors, dtype: int64
#
# style
# False    226
# Name: style, dtype: int64
#
# wheels
# False    226
# Name: wheels, dtype: int64
#
# engine
# False    226
# Name: engine, dtype: int64
#
# base
# False    226
# Name: base, dtype: int64
#
# length
# False    226
# Name: length, dtype: int64
#
# width
# False    226
# Name: width, dtype: int64
#
# heingt
# False    226
# Name: heingt, dtype: int64
#
# curb
# False    226
# Name: curb, dtype: int64
#
# engineType
# False    226
# Name: engineType, dtype: int64
#
# cylinders
# False    226
# Name: cylinders, dtype: int64
#
# engineSize
# False    226
# Name: engineSize, dtype: int64
#
# system
# ...

# %% [markdown]
# <h5 style="color:#483D8B">4.3 Imputacion de valores numericos</h5>

# %%
prom=dfAutos["bore"].astype("float").mean(axis=0)
dfAutos["bore"].replace(np.nan, prom, inplace=True)
prom=dfAutos["stroke"].astype("float").mean(axis=0)
dfAutos["stroke"].replace(np.nan, prom, inplace=True)
prom=dfAutos["horsepower"].astype("float").mean(axis=0)
dfAutos["horsepower"].replace(np.nan, prom, inplace=True)
prom=dfAutos["peak"].astype("float").mean(axis=0)
dfAutos["peak"].replace(np.nan, prom, inplace=True)

# %% [markdown]
# <p>-----------------------------------------------------------------------------------------------------------------------------</p>

# %%
av_normalized = dfAutos["normalized"].astype("float").mean(axis=0)
av_bore = dfAutos["bore"].astype("float").mean(axis=0)
av_stroke = dfAutos["stroke"].astype("float").mean(axis=0)
av_horsepower = dfAutos["horsepower"].astype("float").mean(axis=0)
av_peak = dfAutos["peak"].astype("float").mean(axis=0)

# %%
dfAutos["normalized"].replace(np.nan,av_normalized, inplace = True)
dfAutos["bore"].replace(np.nan,av_bore, inplace = True)
dfAutos["stroke"].replace(np.nan,av_stroke, inplace = True)
dfAutos["horsepower"].replace(np.nan,av_horsepower, inplace = True)
dfAutos["peak"].replace(np.nan,av_peak, inplace = True)
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3  122.283333  alfa-romero  gas        std   two  convertible
# 1          3  122.283333  alfa-romero  gas        std   two  convertible
# 2          1  122.283333  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %%
promNormalizadas=dfAutos["normalized"].astype("float").mean(axis=0)
promNormalizadas
# Out:
# 122.28333333333333

# %%
dfAutos["normalized"].replace(np.nan, promNormalizadas, inplace=True)
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3  122.283333  alfa-romero  gas        std   two  convertible
# 1          3  122.283333  alfa-romero  gas        std   two  convertible
# 2          1  122.283333  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <p>O</p>

# %%
av_normalized = dfAutos["normalized"].astype("float").mean(axis=0)
print('La media es: ',av_normalized)
# Out:
# La media es:  122.28333333333333

# %%
dfAutos["normalized"].replace(np.nan, 122, inplace=True)
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3  122.283333  alfa-romero  gas        std   two  convertible
# 1          3  122.283333  alfa-romero  gas        std   two  convertible
# 2          1  122.283333  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h5 style="color:#483D8B">4.4 Imputacion simple de valores categoricos</h5>

# %%
dfAutos['doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
dfAutos['doors'].replace(np.nan, 'four', inplace=True)
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3  122.283333  alfa-romero  gas        std   two  convertible
# 1          3  122.283333  alfa-romero  gas        std   two  convertible
# 2          1  122.283333  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h5 style="color:#483D8B">4.5 Eliminar filas con valores faltantes</h5>
#
# <p>Eliminar observaciones del DF</p>

# %%
dfAutos.dropna(subset=["price"], axis=0, inplace=True)
dfAutos.reset_index(drop=True, inplace=True)

# %%
dfTemp=dfAutos.isnull()
for column in dfTemp.columns.values.tolist():
    print(column)
    print(dfTemp[column].value_counts())
    print("")
# Out:
# symboling
# False    222
# Name: symboling, dtype: int64
#
# normalized
# False    222
# Name: normalized, dtype: int64
#
# make
# False    222
# Name: make, dtype: int64
#
# fuel
# False    222
# Name: fuel, dtype: int64
#
# aspiration
# False    222
# Name: aspiration, dtype: int64
#
# doors
# False    222
# Name: doors, dtype: int64
#
# style
# False    222
# Name: style, dtype: int64
#
# wheels
# False    222
# Name: wheels, dtype: int64
#
# engine
# False    222
# Name: engine, dtype: int64
#
# base
# False    222
# Name: base, dtype: int64
#
# length
# False    222
# Name: length, dtype: int64
#
# width
# False    222
# Name: width, dtype: int64
#
# heingt
# False    222
# Name: heingt, dtype: int64
#
# curb
# False    222
# Name: curb, dtype: int64
#
# engineType
# False    222
# Name: engineType, dtype: int64
#
# cylinders
# False    222
# Name: cylinders, dtype: int64
#
# engineSize
# False    222
# Name: engineSize, dtype: int64
#
# system
# False    222
# ...

# %%
dfAutos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  222.000000  222.000000  222.000000  222.000000  222.000000
# mean     0.909910   98.661261  174.064865   65.836036   53.766667
# std      1.280198    5.648067   11.720591    1.970382    2.367974
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  167.350000   64.200000   52.000000
# 50%      1.000000   97.250000  173.200000   65.500000   54.100000
# 75%      2.000000  102.300000  180.200000   66.500000   55.675000
# max      3.000000  120.900000  208.100000   72.000000   59.800000
#
#               curb  engineSize  compression        city      higway
# count   222.000000  222.000000   222.000000  222.000000  222.000000
# mean   2540.418919  126.450450    10.323514   25.445946   30.990991
# std     494.544729   40.226562     4.179231    6.272417    6.701787
# min    1488.000000   61.000000     7.000000   13.000000   16.000000
# ...

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    222 non-null    int64
#  1   normalized   222 non-null    object
#  2   make         222 non-null    object
#  3   fuel         222 non-null    object
#  4   aspiration   222 non-null    object
#  5   doors        222 non-null    object
#  6   style        222 non-null    object
#  7   wheels       222 non-null    object
#  8   engine       222 non-null    object
#  9   base         222 non-null    float64
#  10  length       222 non-null    float64
#  11  width        222 non-null    float64
#  12  heingt       222 non-null    float64
#  13  curb         222 non-null    int64
#  14  engineType   222 non-null    object
#  15  cylinders    222 non-null    object
#  16  engineSize   222 non-null    int64
#  17  system       222 non-null    object
# ...

# %% [markdown]
# <p style="text-align: right">07/07/2023</p>
# <p style="text-align: right">Semana 8</p>
#
# <h2 style="color:#50C878">5. Estandarizacion de datos</h2>
#
# <ol>
#     <li>Verificar el Dominio de las variables</li>
#     <li>Convertir valores numericos, en funcion de la               interpretacion del medio</li>
#     <li>Normalizar valores entre 0 y 1</li>
#     <li>Creacion de rangos de valores (Binning)</li>
# </ol>
#
# <h5 style="color:#483D8B">5.1 Verificar el Dominio de las Variables</h5>

# %% [markdown]
# ["normalized"]
# , ["bore"]
# , ["stroke"]
# , ["horsepower"]
# , ["peak"]

# %%
dfAutos[["normalized"]] = dfAutos[["normalized"]].astype("int")
dfAutos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# cylinders       object
# engineSize       int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower      object
# peak            object
# city             int64
# higway           int64
# price           object
# dtype: object

# %%
dfAutos[["horsepower", "peak", "price"]] = dfAutos[["horsepower", "peak", "price"]].astype("int")
dfAutos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# cylinders       object
# engineSize       int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower       int32
# peak             int32
# city             int64
# higway           int64
# price            int32
# dtype: object

# %%
dfAutos[["bore", "stroke"]] = dfAutos[["bore", "stroke"]].astype("float")

dfAutos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# cylinders       object
# engineSize       int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower       int32
# peak             int32
# city             int64
# higway           int64
# price            int32
# dtype: object

# %%
dfAutos.describe()
# Out:
#         symboling  normalized        base      length       width      heingt  \
# count  222.000000  222.000000  222.000000  222.000000  222.000000  222.000000
# mean     0.909910  122.229730   98.661261  174.064865   65.836036   53.766667
# std      1.280198   33.651614    5.648067   11.720591    1.970382    2.367974
# min     -2.000000   65.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000  101.000000   94.500000  167.350000   64.200000   52.000000
# 50%      1.000000  122.000000   97.250000  173.200000   65.500000   54.100000
# 75%      2.000000  136.250000  102.300000  180.200000   66.500000   55.675000
# max      3.000000  256.000000  120.900000  208.100000   72.000000   59.800000
#
#               curb  engineSize        bore      stroke  compression  \
# count   222.000000  222.000000  222.000000  222.000000   222.000000
# mean   2540.418919  126.450450    3.320125    3.280243    10.323514
# ...

# %% [markdown]
# <h5 style="color:#483D8B">5.2 Convertir valores numericos en funcion del medio</h5>

# %%
dfAutos.head(4)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
#
#   horsepower  peak city  higway  price
# 0        111  5000   21      27  13495
# 1        111  5000   21      27  16500
# 2        154  5000   19      26  16500
# 3        102  5500   24      30  13950
#
# [4 rows x 26 columns]

# %%
dfAutos["City L/100km (Calc)"] = 235/dfAutos["city"]
dfAutos["Higway L/100km (Calc)"] = 235/dfAutos["higway"]
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower  peak city  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500   24
# 4    4wd  front  99.4  ...  3.19    3.40          8.0         115  5500   18
#
#    higway  price  City L/100km (Calc)  Higway L/100km (Calc)
# ...

# %%
dfAutos.dtypes
# Out:
# symboling                  int64
# normalized                 int32
# make                      object
# fuel                      object
# aspiration                object
# doors                     object
# style                     object
# wheels                    object
# engine                    object
# base                     float64
# length                   float64
# width                    float64
# heingt                   float64
# curb                       int64
# engineType                object
# cylinders                 object
# engineSize                 int64
# system                    object
# bore                     float64
# stroke                   float64
# compression              float64
# horsepower                 int32
# peak                       int32
# city                       int64
# higway                     int64
# price                      int32
# City L/100km (Calc)      float64
# Higway L/100km (Calc)    float64
# dtype: object

# %% [markdown]
# <h5 style="color:#483D8B">5.3 Normalizar Valores entre 0 y 1</h5>

# %%
dfTemp = dfAutos[["City L/100km (Calc)", "Higway L/100km (Calc)", "engineSize"]]
dfTemp.head(5)
# Out:
#    City L/100km (Calc)  Higway L/100km (Calc)  engineSize
# 0            11.190476               8.703704         130
# 1            11.190476               8.703704         130
# 2            12.368421               9.038462         152
# 3             9.791667               7.833333         109
# 4            13.055556              10.681818         136

# %%
dfTemp.describe()
# Out:
#        City L/100km (Calc)  Higway L/100km (Calc)  engineSize
# count           222.000000             222.000000  222.000000
# mean              9.803749               7.947735  126.450450
# std               2.441520               1.783939   40.226562
# min               4.795918               4.351852   61.000000
# 25%               7.833333               6.911765   98.000000
# 50%               9.400000               7.833333  115.000000
# 75%              11.610119               9.400000  146.000000
# max              18.076923              14.687500  326.000000

# %%
dfAutos["City L/100km (norm)"] = dfAutos["City L/100km (Calc)"]/dfAutos["City L/100km (Calc)"].max()

dfAutos["Higway L/100km (norm)"] = dfAutos["Higway L/100km (Calc)"]/dfAutos["Higway L/100km (Calc)"].max()

dfAutos["engineSize (norm)"] = dfAutos["engineSize"]/dfAutos["engineSize"].max()

dfTemp = dfAutos[["City L/100km (Calc)", "Higway L/100km (Calc)", "engineSize", "City L/100km (norm)", "Higway L/100km (norm)", "engineSize (norm)"]]

dfTemp.head(5)
# Out:
#    City L/100km (Calc)  Higway L/100km (Calc)  engineSize  \
# 0            11.190476               8.703704         130
# 1            11.190476               8.703704         130
# 2            12.368421               9.038462         152
# 3             9.791667               7.833333         109
# 4            13.055556              10.681818         136
#
#    City L/100km (norm)  Higway L/100km (norm)  engineSize (norm)
# 0             0.619048               0.592593           0.398773
# 1             0.619048               0.592593           0.398773
# 2             0.684211               0.615385           0.466258
# 3             0.541667               0.533333           0.334356
# 4             0.722222               0.727273           0.417178

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  horsepower  peak  city  higway  price  \
# 0    rwd  front  88.6  ...         111  5000    21      27  13495
# 1    rwd  front  88.6  ...         111  5000    21      27  16500
# 2    rwd  front  94.5  ...         154  5000    19      26  16500
# 3    fwd  front  99.8  ...         102  5500    24      30  13950
# 4    4wd  front  99.4  ...         115  5500    18      22  17450
#
#   City L/100km (Calc)  Higway L/100km (Calc) City L/100km (norm)  \
# ...

# %% [markdown]
# <h5 style="color:#483D8B">5.4 Crear rangos para agrupar datos</h5>

# %%
dfTemp = dfAutos["horsepower"]
dfTemp.describe()
# Out:
# count    222.000000
# mean     102.180180
# std       36.334344
# min       48.000000
# 25%       70.000000
# 50%       95.000000
# 75%      116.000000
# max      262.000000
# Name: horsepower, dtype: float64

# %%
#bins = np.linspace(min(dfAutos['horsepower']), max(dfAutos['horsepower']), 4)
bins = np.linspace(48,262,4)

bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
categorias = ["Bajo", "Medio", "Alto"]
dfAutos["horsepower (cat)"] = pd.cut(dfAutos['horsepower'], bins, labels=categorias, include_lowest=True)
dfTemp = dfAutos[["horsepower", "horsepower (cat)"]]
dfTemp.head(5)
# Out:
#    horsepower horsepower (cat)
# 0         111             Bajo
# 1         111             Bajo
# 2         154            Medio
# 3         102             Bajo
# 4         115             Bajo

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  peak  city  higway  price City L/100km (Calc)  \
# 0    rwd  front  88.6  ...  5000    21      27  13495           11.190476
# 1    rwd  front  88.6  ...  5000    21      27  16500           11.190476
# 2    rwd  front  94.5  ...  5000    19      26  16500           12.368421
# 3    fwd  front  99.8  ...  5500    24      30  13950            9.791667
# 4    4wd  front  99.4  ...  5500    18      22  17450           13.055556
#
#   Higway L/100km (Calc)  City L/100km (norm) Higway L/100km (norm)  \
# ...

# %% [markdown]
# <p style="text-align: right">07/07/2023</p>
# <p style="text-align: right">Semana 9</p>
#
# <h2 style="color: #50C878">6. Visualización de Datos</h2>
#
# <p>En este apartado se van a crear diferentes visualizaciones (Gráficas), las cuales nos ayudan a realizar la interpretaion y analisis de la informacion del set</p>
# </br>
#
# <p>Estos son tres elementos fundamentales para poder crear las visualizaciones:</p>
# <ol>
#     <li>Preguntas de negocio a responder</li>
#     <li>Pleno conocimiento del set de datos</li>
#     <li>Experiencia de negocio</li>
# </ol>

# %% [markdown]
# <h5 style="color: #483D8B">6.1 Configuración para los Gráficos</h5>
#
# <p>Cuantos Autos existen segun fabricante?
#    Cual fabricante tiene mayor presencia en el parque de Autos? </p>

# %%
#Remueve las lineas de los axis.
mpl.rcParams["axes.spines.bottom"] = True
mpl.rcParams["axes.spines.left"] = False
mpl.rcParams["axes.spines.right"] = False
mpl.rcParams["axes.spines.top"] = False

# %%
gf = dfAutos.groupby(['make']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('symboling', ascending=False)
gf
# Out:
#                symboling
# make
# toyota                46
# volkswagen            24
# nissan                18
# mazda                 17
# mitsubishi            13
# honda                 13
# subaru                12
# peugot                11
# dodge                  9
# bmw                    8
# mercedes-benz          8
# plymouth               7
# saab                   6
# volvo                  6
# audi                   6
# porsche                4
# jaguar                 3
# chevrolet              3
# alfa-romero            3
# renault                2
# isuzu                  2
# mercury                1

# %%
fig, ax = plt.subplots(1,1, figsize =(15,6.9), dpi=100)
 
eje_x = gf.index.tolist()
data = gf["symboling"].tolist()
 
bar_colors = ['#69d2e7','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5',
             '#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5',
             '#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#e5e5e5','#fa6900']
 
ax.barh(eje_x, data, color=bar_colors)
 
#--------------------------------------------------------------------------------------------#
#-----------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EFES DEL GRAFICO----------------#
#--------------------------------------------------------------------------------------------#
#FORMATO DEL TITULO
 
title = "Grafico 1: Vehiculos en Inventario"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif",
             fontname = "serif")
 
#FORMATO DEL SUBTITULO
subTitle = "Cantidad de vehiculos agrupados segun fabricante, en Costa Rica, periodo 2023"
ax.set_title(subTitle,
             horizontalalignment = "left",
             x = 0.001,
             y = 0.80,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")
 
 
#FORMATO AL EJE (X/Y)
etiqueta = "cantidad de carros (ABS)"
ax.set_xlabel(etiqueta,
              ha = 'left',
              fontsize = 10,
              fontweight = "regular",
              fontfamily = "serif")
 
ax.xaxis.set_label_coords(x=0, y=-0.07, transform = ax.transAxes)
 
#FORMATO TAMANO LETRA AMBOS EJES
ax.tick_params(axis='both', labelsize = 10)
 
#CONFIGURA LA UBICACION EL TITULO, SUBTITULO Y GRAFICO
plt.subplots_adjust(top = 0.80)
 
plt.show()

# %%
dfAutos.head(3)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  peak  city  higway  price City L/100km (Calc)  \
# 0    rwd  front  88.6  ...  5000    21      27  13495           11.190476
# 1    rwd  front  88.6  ...  5000    21      27  16500           11.190476
# 2    rwd  front  94.5  ...  5000    19      26  16500           12.368421
#
#   Higway L/100km (Calc)  City L/100km (norm) Higway L/100km (norm)  \
# 0              8.703704             0.619048              0.592593
# 1              8.703704             0.619048              0.592593
# 2              9.038462             0.684211              0.615385
#
#    engineSize (norm)  horsepower (cat)
# 0           0.398773              Bajo
# ...

# %%
gf = dfAutos.groupby(['horsepower']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('symboling', ascending=False)
gf
# Out:
#             symboling
# horsepower
# 68                 21
# 116                14
# 69                 10
# 110                 9
# 70                  9
# 92                  8
# 102                 7
# 95                  7
# 88                  7
# 114                 6
# 101                 6
# 62                  6
# 85                  6
# 84                  5
# 97                  5
# 145                 5
# 90                  5
# 82                  5
# 76                  5
# 52                  4
# 156                 4
# 123                 4
# 160                 4
# 161                 4
# 86                  4
# 111                 4
# 73                  4
# 100                 3
# 182                 3
# 207                 3
# 121                 3
# 152                 3
# 184                 2
# 112                 2
# 56                  2
# 176                 2
# 94                  2
# 155                 2
# 200                 1
# 175                 1
# ...

# %%
fig, ax = plt.subplots(1,1, figsize =(15,6.9), dpi=100)
 
eje_x = gf.index.tolist()
data = gf["symboling"].tolist()
 
bar_colors = ['#69d2e7']
 
ax.bar(eje_x, data, color=bar_colors)
 
#--------------------------------------------------------------------------------------------#
#-----------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EFES DEL GRAFICO----------------#
#--------------------------------------------------------------------------------------------#
#FORMATO DEL TITULO
 
title = "Grafico 2: Vehiculos"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif",
             fontname = "Arial")
 
#FORMATO DEL SUBTITULO
subTitle = "Cantidad de vehiculos agrupados segun caballos de horsepower"
ax.set_title(subTitle,
             horizontalalignment = "left",
             x = 0.001,
             y = 0.80,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")
 
 
#FORMATO AL EJE (X/Y)
etiqueta = "Cantidad de Vehiculos (ABS)"
ax.set_xlabel(etiqueta,
              ha = 'left',
              fontsize = 10,
              fontweight = "regular",
              fontfamily = "serif")
 
ax.xaxis.set_label_coords(x=0, y=-0.07, transform = ax.transAxes)
 
#FORMATO TAMANO LETRA AMBOS EJES
ax.tick_params(axis='both', labelsize = 10)
 
#CONFIGURA LA UBICACION EL TITULO, SUBTITULO Y GRAFICO
plt.subplots_adjust(top = 0.80)
 
plt.show()

# %%
gf = dfAutos.groupby(['horsepower (cat)']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('symboling', ascending=False)
gf
# Out:
#                   symboling
# horsepower (cat)
# Bajo                    174
# Medio                    43
# Alto                      5

# %%
fig, ax = plt.subplots(1,1, figsize =(15,6.9), dpi=100)
 
eje_x = gf.index.tolist()
data = gf["symboling"].tolist()
 
bar_colors = ['#69d2e7']
 
ax.bar(eje_x, data, color=bar_colors)
 
#--------------------------------------------------------------------------------------------#
#-----------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EFES DEL GRAFICO----------------#
#--------------------------------------------------------------------------------------------#
#FORMATO DEL TITULO
 
title = "Grafico 2: Vehiculos"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif",
             fontname = "Arial")
 
#FORMATO DEL SUBTITULO
subTitle = "Cantidad de vehiculos agrupados segun caballos de horsepower"
ax.set_title(subTitle,
             horizontalalignment = "left",
             x = 0.001,
             y = 0.80,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")
 
 
#FORMATO AL EJE (X/Y)
etiqueta = "Cantidad de Vehiculos (ABS)"
ax.set_xlabel(etiqueta,
              ha = 'left',
              fontsize = 10,
              fontweight = "regular",
              fontfamily = "serif")
 
ax.xaxis.set_label_coords(x=0, y=-0.07, transform = ax.transAxes)
 
#FORMATO TAMANO LETRA AMBOS EJES
ax.tick_params(axis='both', labelsize = 10)
 
#CONFIGURA LA UBICACION EL TITULO, SUBTITULO Y GRAFICO
plt.subplots_adjust(top = 0.80)
 
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize =(13,6.9), dpi=60)
 
eje_x = gf.index.tolist()
data = gf["symboling"].tolist()
 
bar_colors = ["#00FA9A",'#69d2e7' , "#6A5ACD"]
ax.pie(data, labels=eje_x, colors=bar_colors, autopct='%1.1f%%')
 
#--------------------------------------------------------------------------------------------#
#-----------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EFES DEL GRAFICO----------------#
#--------------------------------------------------------------------------------------------#
#FORMATO DEL TITULO
 
title = "Grafico 2: Vehiculos"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif",
             fontname = "Arial")
 
#FORMATO DEL SUBTITULO
subTitle = "Cantidad de vehiculos agrupados segun caballos de horsepower"
ax.set_title(subTitle,
             horizontalalignment = "left",
             x = 0.001,
             y = 0.80,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")
 

 
#CONFIGURA LA UBICACION EL TITULO, SUBTITULO Y GRAFICO
plt.subplots_adjust(top = 0.85)
 
plt.show()

# %% [markdown]
# <p>Pregunta 2: Cual es la distribucion de los autos segun su estilo?</p>

# %%
dfAutos.head(2)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
#
#   wheels engine  base  ...  peak  city  higway  price City L/100km (Calc)  \
# 0    rwd  front  88.6  ...  5000    21      27  13495           11.190476
# 1    rwd  front  88.6  ...  5000    21      27  16500           11.190476
#
#   Higway L/100km (Calc)  City L/100km (norm) Higway L/100km (norm)  \
# 0              8.703704             0.619048              0.592593
# 1              8.703704             0.619048              0.592593
#
#    engineSize (norm)  horsepower (cat)
# 0           0.398773              Bajo
# 1           0.398773              Bajo
#
# [2 rows x 32 columns]

# %%
gf = dfAutos.groupby(['style']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('symboling', ascending=False)
gf
# Out:
#              symboling
# style
# sedan              103
# hatchback           75
# wagon               26
# hardtop             10
# convertible          8

# %%
fig, ax = plt.subplots(1,1, figsize =(8,6.9), dpi=90)
 
names = gf.index.tolist()
estilo = gf["symboling"].tolist()    
    
circulo = plt.Circle((0,0), 0.7, color='white')


bar_colors = ["#00FA9A",'#69d2e7' , "#6A5ACD", "#DB7093", "#BA55D3"]
ax.pie(estilo, labels=names, colors=bar_colors, autopct='%1.1f%%')



#--------------------------------------------------------------------------------------------#
#-----------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EFES DEL GRAFICO----------------#
#--------------------------------------------------------------------------------------------#
#FORMATO DEL TITULO
 
title = "Grafico 2: Vehiculos"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif",
             fontname = "Arial")
 
#FORMATO DEL SUBTITULO
subTitle = "Cantidad de vehiculos agrupados segun caballos de horsepower"
ax.set_title(subTitle,
             horizontalalignment = "left",
             x = 0.001,
             y = 0.80,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")
 
#CONFIGURA LA UBICACION EL TITULO, SUBTITULO Y GRAFICO
plt.subplots_adjust(top = 0.78)

#COLOCA EL CIRCULO QUE SE DIBUJO SOBRE EL GRAFICO CIRCULAR
p = plt.gcf()
p.gca().add_artist(circulo)
 
plt.show()

# %% [markdown]
# <p>Pregunta 3: Que relacion tiene el tamaño del moto vrs el consumo de combustible en ciudad?</p>

# %%
fig, ax = plt.subplots(1,1, figsize=(15,6.9), dpi=100)
for color in ['tab:blue', 'tab:orange',]:
    n = 222
    x = dfAutos['engineSize'],
    y = dfAutos['City L/100km (Calc)'],
scale = dfAutos['City L/100km (Calc)'],
ax.scatter(x, y, c=color, label=color, 
           alpha=0.3, edgecolor='none')
    

ax.grid(True)

#--------------------------------------------------------------------------------------------#
#-----------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EFES DEL GRAFICO----------------#
#--------------------------------------------------------------------------------------------#
#FORMATO DEL TITULO
 
title = "Grafico 2: Vehiculos"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif",
             fontname = "Arial")
 
#FORMATO DEL SUBTITULO
subTitle = "Cantidad de vehiculos agrupados segun caballos de horsepower"
ax.set_title(subTitle,
             horizontalalignment = "left",
             x = 0.001,
             y = 0.80,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")
 
 
#FORMATO AL EJE (X/Y)
etiqueta = "Tamaño de motor de los carros"
ax.set_xlabel(etiqueta,
              ha = 'left',
              fontsize = 10,
              fontweight = "regular",
              fontfamily = "serif")

etiquetay = "Consumo Combustible en Ciudad"
ax.set_ylabel(etiquetay,
              ha = 'left',
              fontsize = 10,
              fontweight = "regular",
              fontfamily = "serif")
 
ax.xaxis.set_label_coords(x=0, y=-0.07, transform = ax.transAxes)

ax.yaxis.set_label_coords(x=-0.03, y=0.45, transform = ax.transAxes)

#FORMATO TAMANO LETRA AMBOS EJES
ax.tick_params(axis='both', labelsize = 10)
 
#CONFIGURA LA UBICACION EL TITULO, SUBTITULO Y GRAFICO
plt.subplots_adjust(top = 0.70)

plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(15,6.9), dpi=100)
for color in ['tab:blue', 'tab:orange',]:
    n = 222
    x = dfAutos['engineSize'],
    y = dfAutos['Higway L/100km (Calc)'],
scale = dfAutos['City L/100km (Calc)'],
ax.scatter(x, y, c='#72ae95', label=color, 
           alpha=0.3, edgecolor='none')
    

ax.grid(True)

#--------------------------------------------------------------------------------------------#
#-----------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EFES DEL GRAFICO----------------#
#--------------------------------------------------------------------------------------------#
#FORMATO DEL TITULO
 
title = "Grafico 3: Vehiculos"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif",
             fontname = "Arial")
 
#FORMATO DEL SUBTITULO
subTitle = "Cantidad de vehiculos agrupados segun caballos de horsepower"
ax.set_title(subTitle,
             horizontalalignment = "left",
             x = 0.001,
             y = 0.80,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")
 
 
#FORMATO AL EJE (X/Y)
etiqueta = "Tamaño de motor de los carros"
ax.set_xlabel(etiqueta,
              ha = 'left',
              fontsize = 10,
              fontweight = "regular",
              fontfamily = "serif")

etiquetay = "Consumo Combustible en Ciudad"
ax.set_ylabel(etiquetay,
              ha = 'left',
              fontsize = 10,
              fontweight = "regular",
              fontfamily = "serif")
 
ax.xaxis.set_label_coords(x=0, y=-0.07, transform = ax.transAxes)

ax.yaxis.set_label_coords(x=-0.03, y=0.45, transform = ax.transAxes)

#FORMATO TAMANO LETRA AMBOS EJES
ax.tick_params(axis='both', labelsize = 10)
 
#CONFIGURA LA UBICACION EL TITULO, SUBTITULO Y GRAFICO
plt.subplots_adjust(top = 0.70)

plt.show()

# %%
gf = dfAutos.groupby(['City L/100km (Calc)']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('symboling', ascending=False)
gf
# Out:
#                      symboling
# City L/100km (Calc)
# 9.791667                    29
# 7.580645                    28
# 12.368421                   28
# 8.703704                    20
# 10.217391                   13
# 9.038462                    12
# 13.823529                   10
# 6.351351                     9
# 7.833333                     9
# 9.400000                     9
# 11.190476                    8
# 8.392857                     7
# 11.750000                    5
# 6.184211                     5
# 14.687500                    5
# 10.681818                    4
# 8.103448                     4
# 15.666667                    3
# 13.055556                    2
# 7.121212                     2
# 16.785714                    2
# 4.795918                     1
# 5.000000                     1
# 7.343750                     1
# 6.911765                     1
# 6.714286                     1
# 6.527778                     1
# 5.222222                     1
# ...

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   symboling              222 non-null    int64
#  1   normalized             222 non-null    int32
#  2   make                   222 non-null    object
#  3   fuel                   222 non-null    object
#  4   aspiration             222 non-null    object
#  5   doors                  222 non-null    object
#  6   style                  222 non-null    object
#  7   wheels                 222 non-null    object
#  8   engine                 222 non-null    object
#  9   base                   222 non-null    float64
#  10  length                 222 non-null    float64
#  11  width                  222 non-null    float64
#  12  heingt                 222 non-null    float64
#  13  curb                   222 non-null    int64
# ...

# %%
gf = dfAutos.groupby(['City L/100km (Calc)']).count()
gf = gf.iloc[:,:1]
gf = gf.sort_values('symboling', ascending=False)
gf
# Out:
#                      symboling
# City L/100km (Calc)
# 9.791667                    29
# 7.580645                    28
# 12.368421                   28
# 8.703704                    20
# 10.217391                   13
# 9.038462                    12
# 13.823529                   10
# 6.351351                     9
# 7.833333                     9
# 9.400000                     9
# 11.190476                    8
# 8.392857                     7
# 11.750000                    5
# 6.184211                     5
# 14.687500                    5
# 10.681818                    4
# 8.103448                     4
# 15.666667                    3
# 13.055556                    2
# 7.121212                     2
# 16.785714                    2
# 4.795918                     1
# 5.000000                     1
# 7.343750                     1
# 6.911765                     1
# 6.714286                     1
# 6.527778                     1
# 5.222222                     1
# ...
